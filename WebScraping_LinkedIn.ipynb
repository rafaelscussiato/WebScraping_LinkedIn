# %% [markdown]
# # <font size=12 color=blue>WebScraping:
#    <font size=6 color=green>Vagas de Analista de Dados no feed do LinkedIn

# %% [markdown]
# # 1. Importando as bibliotecas necessárias

# %%
import bs4
import urllib.request as urllib_request
import pandas as pd

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %% [markdown]
# # 2. Criando função de tratamento da HTML

# %%
def trata_html(input):
    return " ".join(input.split()).replace('> <', '><')

# %% [markdown]
# # 3. Extraindo HTML e convertendo em String para tratamento

# %%
response = urlopen('https://www.linkedin.com/')
html = response.read().decode('utf-8') #convertendo tipo Bytes para String
soup = BeautifulSoup(html, 'html.parser') 
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta content="d_homepage-guest-home" name="pageKey"/>
# <!-- --> <meta content="en_US" name="locale"/>
# <meta data-app-version="2.0.747" data-browser-id="41e3db7e-09a7-4bef-832e-ead2efbd585b" data-call-tree-id="AAXTTv+DTA26BRsStlyzyw==" data-enable-core-web-tracking="" data-enable-page-view-heartbeat-tracking="" data-jet-tags="guest-homepage" data-multiproduct-name="homepage-guest-frontend" data-service-name="homepage-guest-frontend" id="config"/>
# <link href="https://www.linkedin.com/" rel="canonical"/>
# <link href="https://de.linkedin.com/" hreflang="de" rel="alternate"/>
# <link href="https://ie.linkedin.com/" hreflang="en-IE" rel="alternate"/>
# <link href="https://www.linkedin.com/" hreflang="en-US" rel="alternate"/>
# <link href="https://pt.linkedin.com/" hreflang="pt" rel="alternate"/>
# <link href="https://il.linkedin.com/" hreflang="en-IL" rel="alternate"/>
# ...
